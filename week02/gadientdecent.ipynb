# %%
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
import numpy as np
import torch

# 데이터 읽기 함수
def load_dataset(file):

  data = np.loadtxt(file)
  print("DATA=",data)
  
  x = data[:,0:-1]
  print("X=",x)
  
  y = np.reshape(data[:,-1],(3,1))
  print("Y=",y)
 
  # 텐서로 변경
  # 이곳을 채우세요.
  x = torch.tensor(x, dtype=torch.float)
  y = torch.tensor(y, dtype=torch.float)

  return (x, y)

# 텐서를 리스트로 바꾸는 함수
def tensor2list(input_tensor):
  return input_tensor.cpu().detach().numpy().tolist()

x, y = load_dataset("/gdrive/My Drive/colab/train.txt")

# 가중치 초기화
w = torch.randn(1)*3.0
print("\nInit: w = {0}\n".format(tensor2list(w)))

# 학습률
alpha = 0.1

# 학습데이터 수
m = y.size(0)

for epoch in range(50):
  cost = 0
  for i in range(m):
    # 이곳을 채우세요.
    cost = cost + ((w * x[i]) - y[i]) * x[i]
  # 이곳을 채우세요.
  cost = 1/m * cost
  w = w - alpha * cost
  print("Epoch {0:d}: w = {1}".format(epoch+1,tensor2list(w)))
# Out:
# DATA= [[1. 1.]
#  [2. 2.]
#  [3. 3.]]
# X= [[1.]
#  [2.]
#  [3.]]
# Y= [[1.]
#  [2.]
#  [3.]]
#
# Init: w = [-4.4765400886535645]
#
# Epoch 1: w = [-1.920821189880371]
# Epoch 2: w = [-0.5577712059020996]
# Epoch 3: w = [0.1691887378692627]
# Epoch 4: w = [0.5569007396697998]
# Epoch 5: w = [0.7636803984642029]
# Epoch 6: w = [0.8739628791809082]
# Epoch 7: w = [0.9327802062034607]
# Epoch 8: w = [0.9641494750976562]
# Epoch 9: w = [0.9808797240257263]
# Epoch 10: w = [0.9898025393486023]
# Epoch 11: w = [0.9945613741874695]
# Epoch 12: w = [0.9970993995666504]
# Epoch 13: w = [0.9984530210494995]
# Epoch 14: w = [0.999174952507019]
# Epoch 15: w = [0.9995599985122681]
# Epoch 16: w = [0.9997653365135193]
# Epoch 17: w = [0.9998748302459717]
# Epoch 18: w = [0.9999332427978516]
# Epoch 19: w = [0.9999644160270691]
# Epoch 20: w = [0.9999810457229614]
# Epoch 21: w = [0.9999898672103882]
# Epoch 22: w = [0.9999946355819702]
# Epoch 23: w = [0.9999971389770508]
# Epoch 24: w = [0.9999984502792358]
# Epoch 25: w = [0.9999991655349731]
# Epoch 26: w = [0.9999995231628418]
# Epoch 27: w = [0.9999997615814209]
# Epoch 28: w = [0.9999998807907104]
# Epoch 29: w = [0.9999999403953552]
# Epoch 30: w = [1.0]
# Epoch 31: w = [1.0]
# Epoch 32: w = [1.0]
# Epoch 33: w = [1.0]
# Epoch 34: w = [1.0]
# Epoch 35: w = [1.0]
# Epoch 36: w = [1.0]
# Epoch 37: w = [1.0]
# Epoch 38: w = [1.0]
# Epoch 39: w = [1.0]
# Epoch 40: w = [1.0]
# Epoch 41: w = [1.0]
# Epoch 42: w = [1.0]
# Epoch 43: w = [1.0]
# Epoch 44: w = [1.0]
# Epoch 45: w = [1.0]
# Epoch 46: w = [1.0]
# Epoch 47: w = [1.0]
# Epoch 48: w = [1.0]
# Epoch 49: w = [1.0]
# Epoch 50: w = [1.0]
