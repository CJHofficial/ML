# %%
import Data
import Plot
import NN_Model
import numpy as np


#학습 데이터 생성
X, y = Data.gen_dataset(numofsamples=9000) #4000 #6000 #9000 #12000

#모델 생성 및 학습
myModel, myHistory = NN_Model.gen_sequential_model(X, y, EPOCHS = 200, VAL_SPLIT = 0.3)

#학습 결과 출력
Plot.print_Loss(myHistory)  

#임의의 데이터로 예측
NN_Model.predict_new_sample( myModel, np.array([0.6, 0.3, 0.8, 0.9]) )
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# hidden_layer1 (Dense)        (None, 8)                 40
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 4)                 36
# _________________________________________________________________
# output_layer (Dense)         (None, 1)                 5
# ...
# Total params: 81
# Trainable params: 81
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 197/197 - 1s - loss: 156.9863 - val_loss: 147.9031
# Epoch 2/200
# 197/197 - 0s - loss: 156.7119 - val_loss: 147.5998
# Epoch 3/200
# 197/197 - 0s - loss: 156.3454 - val_loss: 147.1886
# Epoch 4/200
# 197/197 - 0s - loss: 155.8497 - val_loss: 146.6380
# Epoch 5/200
# 197/197 - 0s - loss: 155.1955 - val_loss: 145.9238
# Epoch 6/200
# ...
